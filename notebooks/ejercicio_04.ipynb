# %% [markdown]
# # Ejercicio 4- Validacion de email

# %%
import sys
sys.path.append('../src')

# %%
from ejercicio_04 import validar_email

# %%
email=input('Ingrese una email: ')
if validar_email(email):
    print("El email es valido")
else:
    print("El email no es valido")
# Out:
# El email es valido
