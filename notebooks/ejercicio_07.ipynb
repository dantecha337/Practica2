# %% [markdown]
# #Ejercicio 7- Sorteo de amigo invisible

# %%
import sys
sys.path.append('../src')

# %%
from ejercicio_07 import realizar_sorteo

# %%
participantes=input("Ingrese los participantes (separados por coma): ")
sorteo=realizar_sorteo(participantes)

if isinstance(sorteo, str):
    print(sorteo)
else:
    print("Sorteo de amigo invisible: ")
    for persona, asignado in sorteo:
        print(f"{persona} → {asignado}")
# Out:
# Sorteo de amigo invisible:
# Ana → Lucia
# Pedro → Mateo
# Lucia → Sofia
# Mateo → Ana
# Sofia → Pedro
