# %%
# Ejercicio 5- Calculadora de costo de envio

# %%
import sys
sys.path.append('../src')

# %%
from ejercicio_05 import calcular_costo

# %%
peso=float(input("Ingrese el peso del paquete (kg): "))
destino=input("Ingrese la zona de destino (local/regional/nacional): ")
costo= calcular_costo(peso,destino)
if costo is None:
    print("Zona no valida. Las zonas disponibles son: local, regional, nacional.")
else:
    print(f"Costo de envio: ${costo}")
# Out:
# Zona no valida. Las zonas disponibles son: local, regional, nacional.
