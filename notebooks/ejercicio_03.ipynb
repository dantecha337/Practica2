# %% [markdown]
# # Ejercicio 3- Filtro de spoilers

# %%
import sys
sys.path.append('../src')

# %%
from ejercicio_03 import filtrar_spoilers

# %%
review = """La película sigue a un grupo de astronautas que
viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo
a través
de tormentas solares y fallos en el sistema de navegación. Al
llegar
a Marte descubren que la base está abandonada y los
suministros
destruidos. Torres decide sacrificar la nave nodriza para
salvar
al equipo y logran volver a la Tierra en una cápsula de
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje
secreto."""
spoilers=input("Ingrese las palabras spoiler (separadas por coma):")
resultado=filtrar_spoilers(review,spoilers)
print(resultado)
# Out:
# ** pelícu** sigue a un grupo de astronautas que
# viajan a Marte
# en una misión de rescate. El capitán Torres lidera al equipo
# a través
# de tormentas so**res y fallos en el sistema de navegación. Al
# llegar
# a Marte descubren que ** base está abandonada y los
# suministros
# destruidos. Torres decide sacrificar ** nave nodriza para
# salvar
# al equipo y logran volver a ** Tierra en una cápsu** de
# emergencia.
# El final reve** que Torres sobrevivió gracias a un pasaje
# secreto.
